# %%
# Import layer
import layer

# %%
# Authenticate your Layer account
layer.login()

# %%
# Fetch the features
transaction_features_df = layer.get_featureset("fraud_detection_features").to_pandas()

#Display the features
transaction_features_df
# Out:
#       INDEX  avg_time_rcv_txn  avg_time_sent_txn  avg_val_rcv  avg_val_sent  \
# 0         1           5498.63               0.00     0.504895      0.000000
# 1         2            648.26               0.00     1.618731      0.000000
# 2         3           8831.65               0.00     1.402192      0.000000
# 3         4           2336.51               0.00     0.950100      0.000000
# 4         5           1426.21               0.00     0.919980      0.000000
# ...     ...               ...                ...          ...           ...
# 9836   9837           4341.67            5853.58    34.421242     12.492320
# 9837   9838           4017.98            4384.05    12.078742      4.010252
# 9838   9839           5058.18            2390.40     8.966316      2.078134
# 9839   9840          10802.79             870.43     0.171221      0.029789
# 9840   9841           5744.90             564.78     4.368236      0.267735
#
# ...

# %%
transaction_features_df.head()
transaction_features_df.info()
transaction_features_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9841 entries, 0 to 9840
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   INDEX                   9841 non-null   int64
#  1   avg_time_rcv_txn        9841 non-null   float64
#  2   avg_time_sent_txn       9841 non-null   float64
#  3   avg_val_rcv             9841 non-null   float64
#  4   avg_val_sent            9841 non-null   float64
#  5   ERC20_total_eth_rcv     9841 non-null   float64
#  6   ERC20_total_eth_sent    9841 non-null   float64
#  7   ERC20_total_eth_tfr     9841 non-null   float64
#  8   ERC20_unique_sent_addr  9841 non-null   float64
#  9   ERC20_unique_tok_rcv    9841 non-null   float64
#  10  flag                    9841 non-null   int64
#  11  max_val_rcv             9841 non-null   float64
#  12  no_created_contracts    9841 non-null   int64
#  13  rcv_txn                 9841 non-null   int64
# ...

# %%
#Let run the model
model = layer.get_model("fraud_detection_model")
trained_classifier = model.get_train()
trained_classifier
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/env/lib/python3.9/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniforge/base/envs/env/lib/python3.9/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# RandomForestClassifier()

# %%
#Let's make prediction
trained_classifier.predict([[0.0, 5498, 341420,0,50,1,1.002204,0.504895,0.0,0.0,26.75944516,0.55819781,0.0, 0.0, 0.0, 2.0
]])
# Out:
# array([0])
